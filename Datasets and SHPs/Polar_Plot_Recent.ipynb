# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("results_poster_final.csv", decimal=".", delimiter = ';')

# %%
df
# Out:
#     Unnamed: 0         Country  \
# 0            2     El Salvador
# 1            4          Mexico
# 2            5          Mexico
# 3            6          Mexico
# 4            7          Canada
# ..         ...             ...
# 88         244  European Union
# 89         245  European Union
# 90         246  European Union
# 91         247  European Union
# 92         248  European Union
#
#    GDP. current prices. in  2020 (Bilions U.S. dollar)  \
# 0                                              24.784
# 1                                           1.040.372
# 2                                           1.040.372
# 3                                           1.040.372
# 4                                           1.600.264
# ..                                                ...
# 88                                            432.894
# 89                                            432.894
# 90                                            432.894
# 91                                            432.894
# 92                                            432.894
#
#    Population in 2020 (Millions) GDP p/capita                Labs  \
# 0                          6.486     3821,286  Oxford-AstraZeneca
# 1                        128.933     8069,104            SputnikV
# 2                        128.933     8069,104     Pfizer/BioNTech
# 3                        128.933     8069,104  Oxford-AstraZeneca
# 4                         38.029     42080,05  Oxford-AstraZeneca
# ..                           ...          ...                 ...
# 88                         8.901  18059.42468     Pfizer/BioNTech
# 89                         8.901  18059.42468  Oxford-AstraZeneca
# 90                         8.901  18059.42468   Johnson & Johnson
# 91                         8.901  18059.42468             Moderna
# 92                         8.901  18059.42468          Sanofi/GSK
#
#        vaccines Potential (1=yes, 0=no)1   Population  Percent_pop_covered  \
# 0     2000000.0                Confirmed    6453553.0            15.495340
# 1    24000000.0                Confirmed  127575529.0             9.406193
# 2    34400000.0                Confirmed  127575529.0            13.482209
# 3    77400000.0                Confirmed  127575529.0            30.334971
# 4    20000000.0                Confirmed   37589262.0            26.603342
# ..          ...                      ...          ...                  ...
# 88  500000000.0                Confirmed  447512041.0            33.518651
# 89  300000000.0                Confirmed  447512041.0            44.691535
# 90  200000000.0                Confirmed  447512041.0            34.635940
# 91  310000000.0                Confirmed  447512041.0            33.518651
# 92  300000000.0                Confirmed  447512041.0                  NaN
#
#     People_covered last_update  total_vaccinations  people_vaccinated  \
# 0        1000000.0  25/02/2021             16000.0            16000.0
# 1       12000000.0  06/03/2021           2765805.0          2162358.0
# 2       17200000.0  06/03/2021           2765805.0          2162358.0
# 3       38700000.0  06/03/2021           2765805.0          2162358.0
# 4       10000000.0  06/03/2021           2329622.0          1765405.0
# ..             ...         ...                 ...                ...
# 88     250000000.0  06/03/2021            802973.0                NaN
# 89     150000000.0  06/03/2021            802973.0                NaN
# 90     200000000.0  06/03/2021            802973.0                NaN
# 91     155000000.0  06/03/2021            802973.0                NaN
# 92     150000000.0  06/03/2021            802973.0                NaN
#
#     people_fully_vaccinated
# 0                       NaN
# 1                  603447.0
# 2                  603447.0
# 3                  603447.0
# 4                  564217.0
# ..                      ...
# 88                      NaN
# 89                      NaN
# 90                      NaN
# 91                      NaN
# 92                      NaN
#
# [93 rows x 15 columns]

# %%
df[df['Country']=='African Union']
# Out:
#     Unnamed: 0        Country  \
# 85         241  African Union
# 86         242  African Union
# 87         243  African Union
#
#    GDP. current prices. in  2020 (Bilions U.S. dollar)  \
# 85                                              3.131
# 86                                              3.131
# 87                                              3.131
#
#    Population in 2020 (Millions) GDP p/capita                Labs  \
# 85                        11.875  1771.627149     Pfizer/BioNTech
# 86                        11.875  1771.627149   Johnson & Johnson
# 87                        11.875  1771.627149  Oxford-AstraZeneca
#
#        vaccines Potential (1=yes, 0=no)1    Population  Percent_pop_covered  \
# 85   50000000.0                Confirmed  1.359998e+09             8.823540
# 86  120000000.0                Confirmed  1.359998e+09            18.382375
# 87  500000000.0                Confirmed  1.359998e+09             1.838236
#
#     People_covered last_update  total_vaccinations  people_vaccinated  \
# 85      25000000.0         NaN                 NaN                NaN
# 86     120000000.0         NaN                 NaN                NaN
# 87     250000000.0         NaN                 NaN                NaN
#
#     people_fully_vaccinated
# 85                      NaN
# 86                      NaN
# 87                      NaN

# %%
df_filtered = df[['Country', 'GDP p/capita', 'Percent_pop_covered']]

# %%
df_filtered[df_filtered['Country']=='Canada']
# Out:
#   Country GDP p/capita  Percent_pop_covered
# 4  Canada     42080,05            26.603342
# 5  Canada     42080,05            58.527353
# 6  Canada     42080,05           101.092700
# 7  Canada     42080,05            53.206684
# 8  Canada     42080,05            95.772032

# %%
df_filtered['GDP p/capita'] = df_filtered['GDP p/capita'].apply(lambda x: x.replace(',','.'))
# Out:
# <ipython-input-32-48c943d9fcd6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['GDP p/capita'] = df_filtered['GDP p/capita'].apply(lambda x: x.replace(',','.'))

# %%
df_filtered['GDP p/capita'] = df_filtered['GDP p/capita'].astype('float')
# Out:
# <ipython-input-33-f41c722d3a3d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['GDP p/capita'] = df_filtered['GDP p/capita'].astype('float')

# %%
a = df_filtered.groupby(['Country']).agg({'GDP p/capita':'mean',
                                      'Percent_pop_covered':'sum'})

# %%
a
# Out:
#                     GDP p/capita  Percent_pop_covered
# Country
# African Union        1771.627149            29.044151
# Argentina            8433.039000            52.293444
# Australia           51885.466000           116.070263
# Azerbaijan           4124.856000             5.401338
# Bangladesh           1887.974000             0.000000
# Bolivia              3321.917000            13.660598
# Brazil               6450.451000            72.410234
# Canada              42080.050000           335.202112
# Chile               12612.322000            99.868531
# China               10582.102000             0.000000
# Colombia             5207.238000            57.582106
# Costa Rica          11629.012000            76.277518
# Dominican Republic   7444.796000            72.105682
# Ecuador              5315.519000            42.271015
# El Salvador          3821.286000            15.495340
# European Union      18059.424680           146.364777
# India                1876.525000            12.287232
# Indonesia            4038.404000             9.237856
# Israel              41559.509000            93.315233
# Japan               39047.860000            69.157009
# Kazakhstan           8781.866000             0.000000
# Malaysia            10192.457000           102.041460
# Mexico               8069.104000            53.223373
# Myanmar              1332.552000             0.000000
# Nepal                1115.557000             3.718603
# New Zealand         38675.319000           136.718883
# Oman                14423.369000             4.377194
# Panama              14090.496000            17.534121
# Philippines          3372.529000            17.111154
# Saudi Arabia        19586.504000             1.146631
# Sri Lanka            3697.889000            19.953472
# Thailand             7295.127000            16.986401
# Turkey               7715.373000            17.929663
# Ukraine              3424.769000             3.659203
# United Kingdom      39228.516000           207.228597
# United States       63051.398000           176.319615
# Uruguay             15331.717000            28.887257
# Uzbekistan           1762.856000            23.187018
# Venezuela            1739.112000            29.033000
# Vietnam              3497.512000            36.036746

# %%
a['Percent_pop_covered'].duplicated().any()
# Out:
# True

# %%
a.sort_values(by = 'GDP p/capita', ascending=True, inplace=True)

# %%
def hex_to_rgb(value):
    '''
    Converts hex to rgb colours
    value: string of 6 characters representing a hex colour.
    Returns: list length 3 of RGB values'''
    value = value.strip("#") # removes hash symbol if present
    lv = len(value)
    return tuple(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3))


def rgb_to_dec(value):
    '''
    Converts rgb to decimal colours (i.e. divides each value by 256)
    value: list (length 3) of RGB values
    Returns: list (length 3) of decimal values'''
    return [v/256 for v in value]

# %%
import matplotlib.colors as mcolors

def get_continuous_cmap(hex_list, float_list=None):
    ''' creates and returns a color map that can be used in heat map figures.
        If float_list is not provided, colour map graduates linearly between each color in hex_list.
        If float_list is provided, each color in hex_list is mapped to the respective location in float_list. 
        
        Parameters
        ----------
        hex_list: list of hex code strings
        float_list: list of floats between 0 and 1, same length as hex_list. Must start with 0 and end with 1.
        
        Returns
        ----------
        colour map'''
    rgb_list = [rgb_to_dec(hex_to_rgb(i)) for i in hex_list]
    if float_list:
        pass
    else:
        float_list = list(np.linspace(0,1,len(rgb_list)))
        
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
good_shit = get_continuous_cmap(['#F17070','#195D7E', '#05997A'])
good_shit

# %%
GDP = a['GDP p/capita']

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm


plt.rcParams.update({'font.size': 50})
import math


N = len(a)
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
r = np.array(a['Percent_pop_covered'])

label = list(a.index.values)

width = np.array([0.15] * N)

ax = plt.subplot(111, projection='polar')
ax.set_rlim(0, 300)
ax.set_rticks(np.arange(0, 101, 20)) #lines
ax.set_thetagrids(theta * 180 / np.pi)
ax.set_yticklabels([]) #position of grid labels
ax.xaxis.grid(False)
ax.yaxis.grid(True, color = '#195D7E', linestyle = '-' )
ax.set_facecolor("#F5F5EF")

#colors = plt.cm.hsv(theta/5/np.pi)


data_color = a['GDP p/capita']


data_color = np.array([x / max(data_color) for x in data_color])

my_cmap = plt.cm.get_cmap(get_continuous_cmap(['#F17070', '#195D7E','#05997A']))
colors = my_cmap(data_color)
ax.spines['polar'].set_visible(False)


ax.bar(x=theta, height=r, width=width, bottom=0, alpha=1, tick_label='', color=colors) #tick_label=label,

from matplotlib.cm import ScalarMappable


sm = ScalarMappable(cmap=my_cmap, norm = mcolors.TwoSlopeNorm(vmin=min(GDP),vcenter=np.median(GDP), vmax=max(GDP)))
sm.set_array([])

cbar = plt.colorbar(sm,)
cbar.set_label('GDP per capita (€)',labelpad=-450, weight='bold', fontsize = 70)
cbar.ax.tick_params(labelsize=70)

plt.gcf().set_size_inches(50, 50)

plt.savefig('polar_plot.png', transparent=True, dpi=200)


plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm


plt.rcParams.update({'font.size': 50})
import math


N = len(a)
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
r = np.array(a['Percent_pop_covered'])

label = list(a.index.values)
width = np.array([0.15] * N)

ax = plt.subplot(111, projection='polar')
ax.set_rlim(0, 300)
ax.set_rticks(np.arange(0, 101, 20)) #lines
ax.set_thetagrids(theta * 180 / np.pi)
ax.set_yticklabels([]) #position of grid labels
ax.xaxis.grid(False)
ax.yaxis.grid(True, color = '#195D7E', linestyle = '-' )
ax.set_facecolor("#F5F5EF")

#colors = plt.cm.hsv(theta/5/np.pi)


data_color = a['GDP p/capita']


data_color = np.array([x / max(data_color) for x in data_color])

my_cmap = plt.cm.get_cmap(get_continuous_cmap(['#F17070', '#195D7E','#05997A']))
colors = my_cmap(data_color)
ax.spines['polar'].set_visible(False)


ax.bar(x=theta, height=r, width=width, bottom=0, alpha=1, tick_label=label
       , color=colors) #tick_label=label,

plt.gcf().set_size_inches(50, 50)

plt.savefig('polar_plot_2.png', transparent=True, dpi=200)


plt.show()

# %%
#a.sort_values(by = 'Percent_pop_covered', ascending=True, inplace=True)

# %%
'''
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm


plt.rcParams.update({'font.size': 30})
import math


N = len(a)
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
r = np.array(a['Percent_pop_covered'])

label = list(a.index.values)

width = np.array([0.15] * N)

ax = plt.subplot(111, projection='polar')

ax.set_rlim(0, 105)
ax.set_rticks(np.arange(0, 101, 10)) #lines
ax.set_thetagrids(theta * 180 / np.pi)
ax.set_rlabel_position(270) #position of grid labels


#colors = plt.cm.hsv(theta/5/np.pi)


data_color = a['GDP p/capita']


data_color = np.array([x / max(data_color) for x in data_color])

my_cmap = plt.cm.get_cmap('RdYlBu')
colors = my_cmap(data_color)



ax.bar(x=theta, height=r, width=width, bottom=0, alpha=1, tick_label=label, color=colors)




from matplotlib.cm import ScalarMappable


sm = ScalarMappable(cmap=my_cmap, norm=plt.Normalize(min(GDP),max(GDP)))
sm.set_array([])

cbar = plt.colorbar(sm)
cbar.set_label('GDP per capita', rotation=270,labelpad=25)

plt.gcf().set_size_inches(50, 50)

#plt.savefig('polar_plot.png', transparent=True)

plt.show()'''
# Out:
# "\nimport numpy as np\nimport matplotlib as mpl\nimport matplotlib.pyplot as plt\nfrom matplotlib import cm\n\n\nplt.rcParams.update({'font.size': 30})\nimport math\n\n\nN = len(a)\ntheta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)\nr = np.array(a['Percent_pop_covered'])\n\nlabel = list(a.index.values)\n\nwidth = np.array([0.15] * N)\n\nax = plt.subplot(111, projection='polar')\n\nax.set_rlim(0, 105)\nax.set_rticks(np.arange(0, 101, 10)) #lines\nax.set_thetagrids(theta * 180 / np.pi)\nax.set_rlabel_position(270) #position of grid labels\n\n\n#colors = plt.cm.hsv(theta/5/np.pi)\n\n\ndata_color = a['GDP p/capita']\n\n\ndata_color = np.array([x / max(data_color) for x in data_color])\n\nmy_cmap = plt.cm.get_cmap('RdYlBu')\ncolors = my_cmap(data_color)\n\n\n\nax.bar(x=theta, height=r, width=width, bottom=0, alpha=1, tick_label=label, color=colors)\n\n\n\n\nfrom matplotlib.cm import ScalarMappable\n\n\nsm = ScalarMappable(cmap=my_cmap, norm=plt.Normalize(min(GDP),max(GDP)))\nsm.set_array([])\n\ncbar = plt.colorbar(sm)\ncbar.set_label('GDP per capita', rotation=270,labelpad=25)\n\nplt.gcf().set_size_inches(50, 50)\n\n#plt.savefig('polar_plot.png', transparent=True)\n\nplt.show()"
